# %% [markdown]
# # Competitive Pokemon Analysis

# %% [markdown]
# While in the traditional pokemon games, players raise Pokemon to complete an adventure, competitive Pokemon is a game where players strategically construct teams of pokemon with moves, natures, items, etc of their choosing to beaet other live players.  Not all Pokemon are equal for this purpose, so based on the usage statistics of the pokemon in competitive play, they are split into various tiers. A player may use a Pokemon to compete in a particular tier if the pokemon is in that tier or below. Historically, usage of various pokemon has changed overtime with the introduction of new pokemon, moves, abilities, and mechanics. So, Pokemon are constantly shifted between tiers to maintain balance.
#
# In this analysis, we will attempt to classify pokemon into the competitive 6v6 tiers based on the properties of the Pokemon themselves.

# %% [markdown]
# ## Data Processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

df = pd.read_csv('pokemon-data.csv', delimiter=';')
mdf = pd.read_csv('move-data.csv', delimiter=';')

print('Number of pokemon: ', len(original))
df.sample()
# Out:
# Number of pokemon:  918
#        Name      Types                   Abilities Tier  HP  Attack  Defense  \
# 51  Bayleef  ['Grass']  ['Leaf Guard', 'Overgrow']  NaN  60      62       80
#
#     Special Attack  Special Defense  Speed Next Evolution(s)  \
# 51              63               80     60      ['Meganium']
#
#                                                 Moves
# 51  ['Tackle', 'Growl', 'Razor Leaf', 'Poison Powd...

# %% [markdown]
# The base stat total is a common metric players use to assess a Pokemon's overall strength, so let's create a column for this.

# %%
df.columns = ['name', 'types', 'abilities', 'tier', 'hp', 'atk', 'def', 'spa', 'spd', 'spe', 'next_evo','moves']
df['bst'] = df['hp'] + df['atk'] + df['def'] + df['spa'] + df['spd'] + df['spe']
df = df[['name', 'types', 'abilities', 'tier', 'hp', 'atk', 'def', 'spa', 'spd', 'spe', 'bst', 'next_evo','moves']]
df.sample()
# Out:
#        name               types                        abilities tier  hp  \
# 623  Pyroar  ['Fire', 'Normal']  ['Moxie', 'Rivalry', 'Unnerve']   PU  86
#
#      atk  def  spa  spd  spe  bst next_evo  \
# 623   68   72  109   66  106  507       []
#
#                                                  moves
# 623  ['Hyper Beam', 'Tackle', 'Leer', 'Ember', 'Wor...

# %% [markdown]
# The next evolution information is not immediately useful; however, we can determine how far a pokemon is in it's evolutionary chain. Notice that a pokemon can have one, two, or three evolutions in it's chain, along with the possibility of a mega evolution. A pokemon that is in its final form that after one evolution is not necessarily weaker or stronger than another after two evolutions. For each pokemon, let's store the length of the evolutionary chain (excluding mega evolutions) and it's stage in the chain.
#
# A mega evolution will be the stage of the pokemon + 1. For example, Blaziken would have a chain length of 3 and it would be in stage 3, while Mega Blaziken would have a chain length of 3 and it would be in stage 4. In this dataset, alternate forms that are strictly better than the original form will be treated the same as mega evolutions.

# %%
def stage_in_evo(n):
    # returns number of evolutions before it
    #print(df[df['name'] == n]['name'])
    bool_arr = df.apply(lambda x: n in eval(x['next_evo']), axis=1) #gets index of previous evolution
    if not any(bool_arr):
        return 1 # if there's nothing before it, it's the first
    else:
        return 1 + stage_in_evo(df.loc[bool_arr, 'name'].values[0])
    
df['stage'] = df.apply(lambda x: stage_in_evo(x['name']), axis=1)

# %%
df.sample()
df[df['name'] == 'Infernape']
#n = 'Thundurus-Therian'
#bool_arr = df.apply(lambda x: n in x['next_evo'] and n!=x['name'], axis=1) # any(n == cur for cur in x['next_evo'])
#df.loc[np.where(bool_arr)[0][0], 'name']
# Out:
#           name                 types               abilities tier  hp  atk  \
# 363  Infernape  ['Fighting', 'Fire']  ['Blaze', 'Iron Fist']   UU  76  104
#
#      def  spa  spd  spe  bst next_evo  \
# 363   71  104   71  108  534       []
#
#                                                  moves  stage
# 363  ['Flare Blitz', 'Scratch', 'Leer', 'Close Comb...      3

# %%
def num_evos(n):
    print(n)
    next_evos = eval(df.loc[np.where(df['name'] == n)[0][0], 'next_evo'])
    if len(next_evos) > 0:
        return num_evos(next_evos[0])
    else:
        return df.loc[np.where(df['name'] == n)[0][0], 'stage']

num_evos('Chimchar')
#original[original['name'] == 'Chimchar']
# Out:
# Chimchar
# Monferno
# Infernape
# name                                                 Infernape
# types                                     ['Fighting', 'Fire']
# abilities                               ['Blaze', 'Iron Fist']
# tier                                                        UU
# hp                                                          76
# atk                                                        104
# def                                                         71
# spa                                                        104
# spd                                                         71
# spe                                                        108
# bst                                                        534
# next_evo                                                    []
# moves        ['Flare Blitz', 'Scratch', 'Leer', 'Close Comb...
# stage                                                        3
# Name: 363, dtype: object

# %%
#original['name'].values
temp = original.loc[original.apply(lambda x: x['name'].find('-') != -1 and x['name'].find('Mega')==-1, axis =1)]
with pd.option_context("display.max_rows", 1000):
    display(temp)
    #print(name + ' Prev: ' + temp.loc[temp.apply(lambda x: name in x['next_evo'] and name != x['name'], axis=1), 'name'].values)
# Out:
#                           name                    types  \
# 7              Aegislash-Blade       ['Steel', 'Ghost']
# 160             Darmanitan-Zen      ['Fire', 'Psychic']
# 171              Deoxys-Attack              ['Psychic']
# 172             Deoxys-Defense              ['Psychic']
# 173               Deoxys-Speed              ['Psychic']
# 183              Diglett-Alola      ['Ground', 'Steel']
# 202              Dugtrio-Alola      ['Ground', 'Steel']
# 231            Exeggutor-Alola      ['Grass', 'Dragon']
# 248            Floette-Eternal                ['Fairy']
# 276              Geodude-Alola     ['Rock', 'Electric']
# 281            Giratina-Origin      ['Dragon', 'Ghost']
# 294                Golem-Alola     ['Rock', 'Electric']
# 305            Gourgeist-Large       ['Ghost', 'Grass']
# 306            Gourgeist-Small       ['Ghost', 'Grass']
# 307            Gourgeist-Super       ['Ghost', 'Grass']
# 310             Graveler-Alola     ['Rock', 'Electric']
# 312               Greninja-Ash        ['Water', 'Dark']
# 314               Grimer-Alola       ['Poison', 'Dark']
# 317             Groudon-Primal       ['Ground', 'Fire']
# 328                   Hakamo-o   ['Dragon', 'Fighting']
# 346                      Ho-Oh       ['Fire', 'Flying']
# 350              Hoopa-Unbound      ['Psychic', 'Dark']
# 366                   Jangmo-o               ['Dragon']
# 393                    Kommo-o   ['Dragon', 'Fighting']
# 400              Kyogre-Primal                ['Water']
# 402               Kyurem-Black        ['Dragon', 'Ice']
# 403               Kyurem-White        ['Dragon', 'Ice']
# 407           Landorus-Therian     ['Flying', 'Ground']
# 447              Lycanroc-Dusk                 ['Rock']
# 448          Lycanroc-Midnight                 ['Rock']
# 476              Marowak-Alola        ['Fire', 'Ghost']
# 487         Meloetta-Pirouette   ['Normal', 'Fighting']
# 488                 Meowstic-F              ['Psychic']
# 489                 Meowstic-M              ['Psychic']
# 491               Meowth-Alola                 ['Dark']
# 510              Minior-Meteor       ['Rock', 'Flying']
# 523                  Muk-Alola       ['Poison', 'Dark']
# 531        Necrozma-Dawn Wings     ['Psychic', 'Ghost']
# 532  Necrozma-Dawn Wings-Ultra    ['Psychic', 'Dragon']
# 533         Necrozma-Dusk Mane     ['Psychic', 'Steel']
# 534   Necrozma-Dusk Mane-Ultra    ['Psychic', 'Dragon']
# 537                  Nidoran-F               ['Poison']
# 538                  Nidoran-M               ['Poison']
# 544            Ninetales-Alola         ['Ice', 'Fairy']
# 559              Oricorio-Pa'u    ['Psychic', 'Flying']
# 560           Oricorio-Pom-Pom   ['Electric', 'Flying']
# 561             Oricorio-Sensu      ['Ghost', 'Flying']
# 579              Persian-Alola                 ['Dark']
# 609                  Porygon-Z               ['Normal']
# 617            Pumpkaboo-Large       ['Ghost', 'Grass']
# 618            Pumpkaboo-Small       ['Ghost', 'Grass']
# 619            Pumpkaboo-Super       ['Ghost', 'Grass']
# 630               Raichu-Alola  ['Electric', 'Psychic']
# 636             Raticate-Alola       ['Dark', 'Normal']
# 638              Rattata-Alola       ['Dark', 'Normal']
# 659                  Rotom-Fan   ['Electric', 'Flying']
# 660                Rotom-Frost      ['Electric', 'Ice']
# 661                 Rotom-Heat     ['Electric', 'Fire']
# 662                  Rotom-Mow    ['Electric', 'Grass']
# 663                 Rotom-Wash    ['Electric', 'Water']
# 675            Sandshrew-Alola         ['Ice', 'Steel']
# 677            Sandslash-Alola         ['Ice', 'Steel']
# 704                Shaymin-Sky      ['Flying', 'Grass']
# 805          Thundurus-Therian   ['Electric', 'Flying']
# 815           Tornadus-Therian               ['Flying']
# 870               Vulpix-Alola                  ['Ice']
# 888          Wishiwashi-School                ['Water']
# 893             Wormadam-Sandy        ['Bug', 'Ground']
# 894             Wormadam-Trash         ['Bug', 'Steel']
# 916                Zygarde-10%     ['Dragon', 'Ground']
# 917           Zygarde-Complete     ['Dragon', 'Ground']
#
#                                             abilities   tier   hp  atk  def  \
# 7                                   ['Stance Change']   Uber   60  150   50
# 160                                      ['Zen Mode']     UU  105   30  105
# 171                                      ['Pressure']   Uber   50  180   20
# 172                                      ['Pressure']   Uber   50   70  160
# 173                                      ['Pressure']   Uber   50   95   90
# 183      ['Sand Force', 'Sand Veil', 'Tangling Hair']     LC   10   55   30
# 202      ['Sand Force', 'Sand Veil', 'Tangling Hair']     PU   35  100   60
# 231                              ['Frisk', 'Harvest']     PU   95  105   85
# 248                      ['Flower Veil', 'Symbiosis']  Limbo   74   65   67
# 276            ['Galvanize', 'Magnet Pull', 'Sturdy']     LC   40   80  100
# 281                                      ['Levitate']   Uber  150  120  100
# 294            ['Galvanize', 'Magnet Pull', 'Sturdy']     PU   80  120  130
# 305                   ['Frisk', 'Insomnia', 'Pickup']     PU   75   95  122
# 306                   ['Frisk', 'Insomnia', 'Pickup']     PU   55   85  122
# 307                   ['Frisk', 'Insomnia', 'Pickup']     PU   85  100  122
# 310            ['Galvanize', 'Magnet Pull', 'Sturdy']    NaN   55   95  115
# 312                                   ['Battle Bond']     OU   72  145   67
# 314  ['Gluttony', 'Poison Touch', 'Power of Alchemy']     LC   80   80   50
# 317                                 ['Desolate Land']   Uber  100  180  160
# 328         ['Bulletproof', 'Overcoat', 'Soundproof']    NaN   55   75   90
# 346                       ['Pressure', 'Regenerator']   Uber  106  130   90
# 350                                      ['Magician']     OU   80  160   60
# 366         ['Bulletproof', 'Overcoat', 'Soundproof']     LC   45   55   65
# 393         ['Bulletproof', 'Overcoat', 'Soundproof']     UU   75  110  125
# 400                                ['Primordial Sea']   Uber  100  150   90
# 402                                      ['Teravolt']     OU  125  170  100
# 403                                    ['Turboblaze']   Uber  125  120   90
# 407                                    ['Intimidate']     OU   89  145   90
# 447                                   ['Tough Claws']     RU   75  117   65
# 448          ['Keen Eye', 'No Guard', 'Vital Spirit']     PU   85  115   75
# 476     ['Cursed Body', 'Lightning Rod', 'Rock Head']     UU   60   80  110
# 487                                  ['Serene Grace']     RU  100  128   90
# 488        ['Competitive', 'Infiltrator', 'Keen Eye']     PU   74   48   76
# 489          ['Infiltrator', 'Keen Eye', 'Prankster']     PU   74   48   76
# 491               ['Pickup', 'Rattled', 'Technician']     LC   40   35   35
# 510                                  ['Shields Down']     NU   60   60  100
# 523  ['Gluttony', 'Poison Touch', 'Power of Alchemy']     UU  105  105   75
# 531                                   ['Prism Armor']   Uber   97  113  109
# 532                                    ['Neuroforce']   Uber   97  167   97
# 533                                   ['Prism Armor']   Uber   97  157  127
# 534                                    ['Neuroforce']   Uber   97  167   97
# 537             ['Hustle', 'Poison Point', 'Rivalry']     LC   55   47   52
# 538             ['Hustle', 'Poison Point', 'Rivalry']     LC   46   57   40
# 544                    ['Snow Cloak', 'Snow Warning']   UUBL   73   67   75
# 559                                        ['Dancer']     PU   75   70   70
# 560                                        ['Dancer']     PU   75   70   70
# 561                                        ['Dancer']     PU   75   70   70
# 579             ['Fur Coat', 'Rattled', 'Technician']     PU   65   60   60
# 609          ['Adaptability', 'Analytic', 'Download']   UUBL   85   80   70
# 617                   ['Frisk', 'Insomnia', 'Pickup']     LC   54   66   70
# 618                   ['Frisk', 'Insomnia', 'Pickup']     LC   44   66   70
# 619                   ['Frisk', 'Insomnia', 'Pickup']     LC   59   66   70
# 630                                  ['Surge Surfer']     PU   60   85   50
# 636               ['Gluttony', 'Hustle', 'Thick Fat']     PU   75   71   70
# 638               ['Gluttony', 'Hustle', 'Thick Fat']     LC   30   56   35
# 659                                      ['Levitate']     PU   50   65  107
# 660                                      ['Levitate']     PU   50   65  107
# 661                                      ['Levitate']     RU   50   65  107
# 662                                      ['Levitate']     RU   50   65  107
# 663                                      ['Levitate']     OU   50   65  107
# 675                      ['Slush Rush', 'Snow Cloak']     LC   50   75   90
# 677                      ['Slush Rush', 'Snow Cloak']     PU   75  100  120
# 704                                  ['Serene Grace']   Uber  100  103   75
# 805                                   ['Volt Absorb']   UUBL   79  105   70
# 815                                   ['Regenerator']     OU   79  100   80
# 870                    ['Snow Cloak', 'Snow Warning']     LC   38   41   40
# 888                                     ['Schooling']     PU   45  140  130
# 893                      ['Anticipation', 'Overcoat']     PU   60   79  105
# 894                      ['Anticipation', 'Overcoat']     PU   60   69   95
# 916                 ['Aura Break', 'Power Construct']     RU   54  100   71
# 917                               ['Power Construct']   Uber  216  100  121
#
#      spa  spd  spe             next_evo  \
# 7    150   50   60                   []
# 160  140  105   55                   []
# 171  180   20  150                   []
# 172   70  160   90                   []
# 173   95   90  180                   []
# 183   35   45   90    ['Dugtrio-Alola']
# 202   50   70  110                   []
# 231  125   75   45                   []
# 248  125  128   92                   []
# 276   30   30   20   ['Graveler-Alola']
# 281  120  100   90                   []
# 294   55   65   45                   []
# 305   58   75   69                   []
# 306   58   75   99                   []
# 307   58   75   54                   []
# 310   45   45   35      ['Golem-Alola']
# 312  153   71  132                   []
# 314   40   50   25        ['Muk-Alola']
# 317  150   90   90                   []
# 328   65   70   65          ['Kommo-o']
# 346  110  154   90                   []
# 350  170  130   80                   []
# 366   45   45   45         ['Hakamo-o']
# 393  100  105   85                   []
# 400  180  160   90                   []
# 402  120   90   95                   []
# 403  170  100   95                   []
# 407  105   80   91                   []
# 447   55   65  110                   []
# 448   55   75   82                   []
# 476   50   80   45                   []
# 487   77   77  128                   []
# 488   83   81  104                   []
# 489   83   81  104                   []
# 491   50   40   90    ['Persian-Alola']
# 510   60  100   60                   []
# 523   65  100   50                   []
# 531  157  127   77                   []
# 532  167   97  129                   []
# 533  113  109   77                   []
# 534  167   97  129                   []
# 537   40   40   41         ['Nidorina']
# 538   40   40   50         ['Nidorino']
# 544   81  100  109                   []
# 559   98   70   93                   []
# 560   98   70   93                   []
# 561   98   70   93                   []
# 579   75   65  115                   []
# 609  135   75   90                   []
# 617   44   55   46  ['Gourgeist-Large']
# 618   44   55   56  ['Gourgeist-Small']
# 619   44   55   41  ['Gourgeist-Super']
# 630   95   85  110                   []
# 636   40   80   77                   []
# 638   25   35   72   ['Raticate-Alola']
# 659  105  107   86                   []
# 660  105  107   86                   []
# 661  105  107   86                   []
# 662  105  107   86                   []
# 663  105  107   86                   []
# 675   10   35   40  ['Sandslash-Alola']
# 677   25   65   65                   []
# 704  120   75  127                   []
# 805  145   80  101                   []
# 815  110   90  121                   []
# 870   50   65   65  ['Ninetales-Alola']
# 888  140  135   30                   []
# 893   59   85   36                   []
# 894   69   95   36                   []
# 916   61   85  115                   []
# 917   91   95   85                   []
#
#                                                  moves  stage
# 7    ['Fury Cutter', 'Pursuit', 'Autotomize', 'Shad...      2
# 160  ['Tackle', 'Rollout', 'Incinerate', 'Hammer Ar...      2
# 171  ['Leer', 'Wrap', 'Night Shade', 'Teleport', 'T...      2
# 172  ['Leer', 'Wrap', 'Night Shade', 'Teleport', 'K...      2
# 173  ['Leer', 'Wrap', 'Night Shade', 'Double Team',...      2
# 183  ['Sand Attack', 'Metal Claw', 'Growl', 'Astoni...      2
# 202  ['Sand Tomb', 'Sand Tomb', 'Rototiller', 'Nigh...      2
# 231  ['Dragon Hammer', 'Dragon Hammer', 'Seed Bomb'...      2
# 248  ['Tackle', 'Vine Whip', 'Fairy Wind', 'Fairy W...      2
# 276  ['Tackle', 'Defense Curl', 'Charge', 'Rock Pol...      2
# 281  ['Dragon Breath', 'Scary Face', 'Ominous Wind'...      2
# 294  ['Heavy Slam', 'Tackle', 'Defense Curl', 'Char...      2
# 305  ['Explosion', 'Phantom Force', 'Trick', 'Aston...      2
# 306  ['Explosion', 'Phantom Force', 'Trick', 'Aston...      2
# 307  ['Explosion', 'Phantom Force', 'Trick', 'Aston...      2
# 310  ['Tackle', 'Defense Curl', 'Charge', 'Rock Pol...      2
# 312  ['Water Shuriken', 'Water Shuriken', 'Night Sl...      2
# 314  ['Pound', 'Poison Gas', 'Harden', 'Bite', 'Dis...      2
# 317  ['Ancient Power', 'Mud Shot', 'Scary Face', 'A...      2
# 328  ['Sky Uppercut', 'Sky Uppercut', 'Autotomize',...      2
# 346  ['Sacred Fire', 'Whirlwind', 'Safeguard', 'Wea...      2
# 350  ['Hyperspace Fury', 'Trick', 'Destiny Bond', '...      2
# 366  ['Tackle', 'Leer', 'Bide', 'Protect', 'Dragon ...      2
# 393  ['Clanging Scales', 'Clanging Scales', 'Sky Up...      2
# 400  ['Ancient Power', 'Water Pulse', 'Scary Face',...      2
# 402  ['Icy Wind', 'Dragon Rage', 'Imprison', 'Ancie...      2
# 403  ['Icy Wind', 'Dragon Rage', 'Imprison', 'Ancie...      2
# 407  ['Outrage', 'Hammer Arm', 'Fissure', 'Block', ...      2
# 447  ['Thrash', 'Thrash', 'Accelerock', 'Counter', ...      2
# 448  ['Counter', 'Counter', 'Reversal', 'Taunt', 'T...      2
# 476  ['Growl', 'Tail Whip', 'Bone Club', 'Flame Whe...      2
# 487  ['Round', 'Quick Attack', 'Confusion', 'Sing',...      2
# 488  ['Stored Power', 'Me First', 'Magical Leaf', '...      2
# 489  ['Quick Guard', 'Mean Look', 'Helping Hand', '...      2
# 491  ['Scratch', 'Growl', 'Bite', 'Fake Out', 'Fury...      2
# 510  ['Tackle', 'Defense Curl', 'Rollout', 'Confuse...      2
# 523  ['Venom Drench', 'Venom Drench', 'Pound', 'Poi...      2
# 531  ['Moonlight', 'Morning Sun', 'Charge Beam', 'M...      2
# 532  ['Moonlight', 'Morning Sun', 'Charge Beam', 'M...      2
# 533  ['Moonlight', 'Morning Sun', 'Charge Beam', 'M...      2
# 534  ['Moonlight', 'Morning Sun', 'Charge Beam', 'M...      2
# 537  ['Growl', 'Scratch', 'Tail Whip', 'Tackle', 'S...      2
# 538  ['Leer', 'Peck', 'Focus Energy', 'Tackle', 'Ho...      2
# 544  ['Dazzling Gleam', 'Dazzling Gleam', 'Imprison...      2
# 559  ['Pound', 'Growl', 'Peck', 'Helping Hand', 'Ai...      2
# 560  ['Pound', 'Growl', 'Peck', 'Helping Hand', 'Ai...      2
# 561  ['Pound', 'Growl', 'Peck', 'Helping Hand', 'Ai...      2
# 579  ['Swift', 'Swift', 'Quash', 'Play Rough', 'Swi...      2
# 609  ['Trick Room', 'Zap Cannon', 'Magic Coat', 'Co...      2
# 617  ['Trick', 'Astonish', 'Confuse Ray', 'Scary Fa...      2
# 618  ['Trick', 'Astonish', 'Confuse Ray', 'Scary Fa...      2
# 619  ['Trick', 'Astonish', 'Confuse Ray', 'Scary Fa...      2
# 630  ['Psychic', 'Psychic', 'Speed Swap', 'Thunder ...      2
# 636  ['Scary Face', 'Scary Face', 'Swords Dance', '...      2
# 638  ['Tackle', 'Tail Whip', 'Quick Attack', 'Focus...      2
# 659  ['Discharge', 'Charge', 'Trick', 'Astonish', '...      2
# 660  ['Discharge', 'Charge', 'Trick', 'Astonish', '...      2
# 661  ['Discharge', 'Charge', 'Trick', 'Astonish', '...      2
# 662  ['Discharge', 'Charge', 'Trick', 'Astonish', '...      2
# 663  ['Discharge', 'Charge', 'Trick', 'Astonish', '...      2
# 675  ['Scratch', 'Defense Curl', 'Bide', 'Powder Sn...      2
# 677  ['Icicle Spear', 'Icicle Spear', 'Metal Burst'...      2
# 704  ['Growth', 'Magical Leaf', 'Leech Seed', 'Quic...      2
# 805  ['Thrash', 'Hammer Arm', 'Nasty Plot', 'Charge...      2
# 815  ['Thrash', 'Hammer Arm', 'Hurricane', 'Tailwin...      2
# 870  ['Powder Snow', 'Tail Whip', 'Roar', "Baby'Dol...      2
# 888  ['Water Gun', 'Growl', 'Helping Hand', 'Feint ...      2
# 893  ['Quiver Dance', 'Quiver Dance', 'Sucker Punch...      2
# 894  ['Quiver Dance', 'Quiver Dance', 'Metal Burst'...      2
# 916  ['Glare', 'Bulldoze', 'Dragon Breath', 'Bite',...      2
# 917  ['Glare', 'Bulldoze', 'Dragon Breath', 'Bite',...      2

# %% [markdown]
# As of generation 7, there are 8 playable tiers. From strongest to weakest: Anything Goes (AG), Uber, Overused (OU), Underused (UU), Rarelyused (RU), Neverused (NU), Partiallyused (PU) and Little Cup (LC). There are also unplayable tiers called borderline tiers, suffixed by BL. These serve as banlists for their respective tiers (so these pokemon can only be used in higher tiers). For the purpose of this analysis, we will classify BL pokemon as the tier above.
#
# We will not consider the Little Cup (LC) format, as they are not defined by usage statistics (it involves pokemon that are not evolved but are capable of evolution and can be obtained in the traditional games at level 5). We will also discard the AG tier, as it was created solely for Mega Rayquaza. Both Pokemon that belong to no tier because they are uncompetitive and pokemon in the Limbo tier becuase they are unreleased will not be considererd.
#
# Let's make these changes.

# %%
df.loc[df.tier == 'OUBL','tier'] = 'Uber'
df.loc[df.tier == 'UUBL','tier'] = 'OU'
df.loc[df.tier == 'RUBL','tier'] = 'UU'
df.loc[df.tier == 'NUBL','tier'] = 'RU'
df.loc[df.tier == 'PUBL','tier'] = 'NU'
df = df[df['tier'].isin(['Uber', 'OU', 'UU', 'NU', 'RU', 'PU'])]

ax = df.tier.value_counts().plot(kind='pie', autopct='%1.1f%%')
print('Total number of Pokemon: ', len(df))
# Out:
# Total number of Pokemon:  552

# %% [markdown]
# All the upper tiers are similar in size by design, but the PU tier is a dump of all the least used pokemon. We must account for this later.
